# %% [markdown]
# **OBJECTIVE:** The point of this notebook is to read data scrapped from our crawlers and to check that we're collecting the right things (not for analysis)
#
# **LAST UPDATED:** 24 April 2024

# %% [markdown]
# **Imports**

# %%
import pandas as pd

# %% [markdown]
# # ⚙️ Set up
#
# 1. Read the main README.md for instructions on how to set up VSCode and the conda environment. Use the `poc-lse-search` environment.
#
# 2. Run the DSI crawler (the only one available at the moment) to get the data.
#
#     ```bash
#     scrapy crawl dsi_crawler
#     ```
#
# 3. Run the rest of the notebook to check the data.

# %% [markdown]
# # The data

# %%
# Confirms that we have a dataframe with 4 columns (Origin URL, URL, Title, Text)
pd.read_json("../data/output.jl", lines=True)
# Out:
#                    origin_url  \
# 0   https://www.lse.ac.uk/DSI
# 1   https://www.lse.ac.uk/DSI
# 2   https://www.lse.ac.uk/DSI
# 3   https://www.lse.ac.uk/DSI
# 4   https://www.lse.ac.uk/DSI
# 5   https://www.lse.ac.uk/DSI
# 6   https://www.lse.ac.uk/DSI
# 7   https://www.lse.ac.uk/DSI
# 8   https://www.lse.ac.uk/DSI
# 9   https://www.lse.ac.uk/DSI
# 10  https://www.lse.ac.uk/DSI
# 11  https://www.lse.ac.uk/DSI
# 12  https://www.lse.ac.uk/DSI
# 13  https://www.lse.ac.uk/DSI
# 14  https://www.lse.ac.uk/DSI
# 15  https://www.lse.ac.uk/DSI
# 16  https://www.lse.ac.uk/DSI
# 17  https://www.lse.ac.uk/DSI
# 18  https://www.lse.ac.uk/DSI
# 19  https://www.lse.ac.uk/DSI
# 20  https://www.lse.ac.uk/DSI
# 21  https://www.lse.ac.uk/DSI
# 22  https://www.lse.ac.uk/DSI
# 23  https://www.lse.ac.uk/DSI
# 24  https://www.lse.ac.uk/DSI
# 25  https://www.lse.ac.uk/DSI
#
#                                                   url  \
# 0                          /DSI/News/Discover-the-DSI
# 1                          /DSI/News/DSI-Announcement
# 2                      /DSI/Turing-University-Network
# 3                                          /DSI/study
# 4   https://www.lse.ac.uk/study-at-lse/Undergradua...
# 5   https://www.lse.ac.uk/study-at-lse/executive-e...
# 6                                         /DSI/Events
# 7   https://www.lse.ac.uk/school-of-public-policy/...
# 8    https://youtu.be/hwrvimZuU0w?si=tIrsFRqMvMn9ToOS
# 9   https://www.lse.ac.uk/lse-player?id=1ea831b4-3...
# 10  https://blogs.lse.ac.uk/studentsatlse/2024/04/...
# 11  https://blogs.lse.ac.uk/europpblog/2024/03/22/...
# 12  https://www.lse.ac.uk/Events/LSE-Festival/2024...
# 13  https://www.imperial.ac.uk/data-science/partne...
# 14  https://www.lse.ac.uk/lse-player?id=1ea831b4-3...
# 15  https://www.lse.ac.uk/DSI/Turing-University-Ne...
# 16  https://www.lse.ac.uk/school-of-public-policy/...
# 17                    https://www.lse.ac.uk/DSI/study
# 18                   https://www.lse.ac.uk/DSI/Events
# 19  https://www.lse.ac.uk/study-at-lse/executive-e...
# 20  https://www.lse.ac.uk/Events/LSE-Festival/2024...
# 21    https://www.lse.ac.uk/DSI/News/Discover-the-DSI
# 22  https://blogs.lse.ac.uk/studentsatlse/2024/04/...
# 23  https://blogs.lse.ac.uk/europpblog/2024/03/22/...
# 24    https://www.lse.ac.uk/DSI/News/DSI-Announcement
# 25  https://www.lse.ac.uk/study-at-lse/undergradua...
#
#                                                 title  \
# 0                       Embedding data science at LSE
# 1                                            DSI News
# 2                           Turing University Network
# 3                    Study Data Science and AI at LSE
# 4                       BSc Politics and Data Science
# 5                                   Executive Courses
# 6                                              Events
# 7                                      Upcoming Event
# 8                                     Event Recording
# 9                                       Event Podcast
# 10                                               Blog
# 11                                               Blog
# 12                                  LSE Festival 2024
# 13            Generative AI and the Knowledge Economy
# 14                                         LSE Player
# 15                      The Turing University Network
# 16  Beveridge 2.0: AI and Data Science for Public ...
# 17                                              Study
# 18                                             Events
# 19  Data Science and AI for Executives On Campus P...
# 20  AI guardians: who holds power over our data | ...
# 21                      Embedding data science at LSE
# 22                  Studying AI at LSE | Students@LSE
# 23  What role should AI play in global health? | E...
# 24                       An announcement from the DSI
# 25                BSc Politics and Data Science - LSE
#
#                                                  html  \
# 0   <div class="component__details">\n            ...
# 1   <div class="component__details">\n            ...
# 2   <div class="component__details">\n            ...
# 3   <div class="component__details">\n            ...
# 4   <div class="component__details">\n            ...
# 5   <div class="component__details">\n            ...
# 6   <div class="component__details">\n            ...
# 7   <div class="component__details">\n            ...
# 8   <div class="component__details">\n            ...
# 9   <div class="component__details">\n            ...
# 10  <div class="component__details">\n            ...
# 11  <div class="component__details">\n            ...
# 12  <div class="component__details">\n            ...
# 13  <div class="component__details">\n            ...
# 14  <!DOCTYPE html>\n\n<html lang="en-GB">\n<head>...
# 15  <!DOCTYPE html>\n\n<html lang="en-GB">\n<head>...
# 16  <!DOCTYPE html>\n\n<html lang="en-GB">\n<head>...
# 17  <!DOCTYPE html>\n\n<html lang="en-GB">\n<head>...
# 18  <!DOCTYPE html>\n\n<html lang="en-GB">\n<head>...
# 19  <!doctype html><html itemscope itemtype="http:...
# 20  <!DOCTYPE html>\n\n<html lang="en-GB">\n  \n  ...
# 21  <!DOCTYPE html>\n\n<html lang="en-GB">\n<head>...
# 22  <!doctype html>\n<html lang=&quot;en-US&quot;>...
# 23  <!doctype html>\n<html lang=&quot;en-US&quot;>...
# 24  <!DOCTYPE html>\n\n<html lang="en-GB">\n<head>...
# 25  <!doctype html><html lang="en" dir="ltr"><head...
#
#                      date_scraped
# 0   Wed, 24 Apr 2024 21:32:42 GMT
# 1   Wed, 24 Apr 2024 21:32:42 GMT
# 2   Wed, 24 Apr 2024 21:32:42 GMT
# 3   Wed, 24 Apr 2024 21:32:42 GMT
# 4   Wed, 24 Apr 2024 21:32:42 GMT
# 5   Wed, 24 Apr 2024 21:32:42 GMT
# 6   Wed, 24 Apr 2024 21:32:42 GMT
# 7   Wed, 24 Apr 2024 21:32:42 GMT
# 8   Wed, 24 Apr 2024 21:32:42 GMT
# 9   Wed, 24 Apr 2024 21:32:42 GMT
# 10  Wed, 24 Apr 2024 21:32:42 GMT
# 11  Wed, 24 Apr 2024 21:32:42 GMT
# 12  Wed, 24 Apr 2024 21:32:42 GMT
# 13  Wed, 24 Apr 2024 21:32:42 GMT
# 14  Wed, 24 Apr 2024 21:33:25 GMT
# 15  Wed, 24 Apr 2024 21:33:25 GMT
# 16  Wed, 24 Apr 2024 21:23:53 GMT
# 17  Wed, 24 Apr 2024 21:33:25 GMT
# 18  Wed, 24 Apr 2024 21:33:25 GMT
# 19  Wed, 24 Apr 2024 21:33:26 GMT
# 20  Wed, 24 Apr 2024 21:33:26 GMT
# 21  Wed, 24 Apr 2024 21:13:33 GMT
# 22  Wed, 24 Apr 2024 22:10:47 GMT
# 23  Wed, 24 Apr 2024 22:10:47 GMT
# 24  Wed, 24 Apr 2024 21:33:25 GMT
# 25  Wed, 24 Apr 2024 21:33:26 GMT
