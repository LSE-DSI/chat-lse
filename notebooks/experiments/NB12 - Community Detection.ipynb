# %%
from neo4j import GraphDatabase
import pandas as pd
from dotenv import load_dotenv
import os

# %%
# Replace with your Neo4j Aura connection details
load_dotenv()
neo4j_url = os.getenv("NEO4J_URI")
neo4j_user = os.getenv("NEO4J_USERNAME")
neo4j_password = os.getenv("NEO4J_PASSWORD")
gds = GraphDatabase.driver(neo4j_url, auth = (neo4j_user, neo4j_password))

def run_query_and_save_to_csv(tx, query, file_name):
    result = tx.run(query)
    df = pd.DataFrame([record.data() for record in result])
    df.to_csv(file_name, index=False)

# %%
with driver.session() as session:
    # Run and save nodes to CSV
    session.execute_read(run_query_and_save_to_csv, "MATCH (n) RETURN n", "nodes.csv")
    
    # Run and save relationships to CSV
    session.execute_read(run_query_and_save_to_csv, "MATCH ()-[r]->() RETURN r", "relationships.csv")

driver.close()
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 with driver.session() as session:
#       2     # Run and save nodes to CSV
# ----> 3     session.execute_read(run_query_and_save_to_csv, "MATCH (n) RETURN n", "nodes.csv")
#       5     # Run and save relationships to CSV
#       6     session.execute_read(run_query_and_save_to_csv, "MATCH ()-[r]->() RETURN r", "relationships.csv")
#
# File /opt/miniconda3/envs/chat-lse/lib/python3.11/site-packages/neo4j/_sync/work/session.py:663, in Session.execute_read(self, transaction_function, *args, **kwargs)
#     594 @NonConcurrentMethodChecker.non_concurrent_method
#     595 def execute_read(
#     596     self,
#    (...)
#     600     *args: _P.args, **kwargs: _P.kwargs
#     601 ) -> _R:
#     602     """Execute a unit of work in a managed read transaction.
#     603
#     604     .. note::
#    (...)
#     661     .. versionadded:: 5.0
#     662     """
# --> 663     return self._run_transaction(
#     664         READ_ACCESS, TelemetryAPI.TX_FUNC,
#     665         transaction_function, args, kwargs
#     666     )
#
# File /opt/miniconda3/envs/chat-lse/lib/python3.11/site-packages/neo4j/_sync/work/session.py:545, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     543 while True:
#     544     try:
# --> 545         self._open_transaction(
#     546             tx_cls=ManagedTransaction,
#     547             api=None if telemetry_sent else api,
#     548             access_mode=access_mode, metadata=metadata,
#     549             timeout=timeout, api_success_cb=api_success_cb,
#     550         )
#     551         assert isinstance(self._transaction, ManagedTransaction)
#     552         tx = self._transaction
#
# File /opt/miniconda3/envs/chat-lse/lib/python3.11/site-packages/neo4j/_sync/work/session.py:424, in Session._open_transaction(self, tx_cls, access_mode, api, metadata, timeout, api_success_cb)
#     413 def _open_transaction(
#     414     self,
#     415     *,
#    (...)
#     422     api_success_cb: t.Optional[t.Callable[[dict], None]] = None,
#     423 ) -> None:
# --> 424     self._connect(access_mode=access_mode)
#     425     assert self._connection is not None
#     426     if api is not None:
#
# File /opt/miniconda3/envs/chat-lse/lib/python3.11/site-packages/neo4j/_sync/work/session.py:130, in Session._connect(self, access_mode, **acquire_kwargs)
#     128     access_mode = self._config.default_access_mode
#     129 try:
# --> 130     super()._connect(
#     131         access_mode, auth=self._config.auth, **acquire_kwargs
#     132     )
#     133 except asyncio.CancelledError:
#     134     self._handle_cancellation(message="_connect")
#
# File /opt/miniconda3/envs/chat-lse/lib/python3.11/site-packages/neo4j/_sync/work/workspace.py:182, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     173 acquire_kwargs_ = {
#     174     "access_mode": access_mode,
#     175     "timeout": acquisition_timeout,
#    (...)
#     179     "liveness_check_timeout": None,
#     180 }
#     181 acquire_kwargs_.update(acquire_kwargs)
# --> 182 self._connection = self._pool.acquire(**acquire_kwargs_)
#     183 self._connection_access_mode = access_mode
#
# File /opt/miniconda3/envs/chat-lse/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:526, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout)
#     523 log.debug("[#0000]  _: <POOL> acquire direct connection, "
#     524           "access_mode=%r, database=%r", access_mode, database)
#     525 deadline = Deadline.from_timeout_or_deadline(timeout)
# --> 526 return self._acquire(
#     527     self.address, auth, deadline, liveness_check_timeout
#     528 )
#
# File /opt/miniconda3/envs/chat-lse/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:313, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout)
#     308             raise ClientError(
#     309                 "failed to obtain a connection from the pool within "
#     310                 "{!r}s (timeout)".format(deadline.original_timeout)
#     311             )
#     312 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 313 return connection_creator()
#
# File /opt/miniconda3/envs/chat-lse/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:163, in IOPool._acquire_new_later.<locals>.connection_creator()
#     161 try:
#     162     try:
# --> 163         connection = self.opener(
#     164             address, auth or self.pool_config.auth, deadline
#     165         )
#     166     except ServiceUnavailable:
#     167         self.deactivate(address)
#
# File /opt/miniconda3/envs/chat-lse/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:500, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     499 def opener(addr, auth_manager, deadline):
# --> 500     return Bolt.open(
#     501         addr, auth_manager=auth_manager, deadline=deadline,
#     502         routing_context=None, pool_config=pool_config
#     503     )
#
# File /opt/miniconda3/envs/chat-lse/lib/python3.11/site-packages/neo4j/_sync/io/_bolt.py:498, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     496 connection.socket.set_deadline(deadline)
#     497 try:
# --> 498     connection.hello()
#     499 finally:
#     500     connection.socket.set_deadline(None)
#
# File /opt/miniconda3/envs/chat-lse/lib/python3.11/site-packages/neo4j/_sync/io/_bolt5.py:575, in Bolt5x2.hello(self, dehydration_hooks, hydration_hooks)
#     573 self.logon(dehydration_hooks, hydration_hooks)
#     574 self.send_all()
# --> 575 self.fetch_all()
#     576 check_supported_server_product(self.server_info.agent)
#
# File /opt/miniconda3/envs/chat-lse/lib/python3.11/site-packages/neo4j/_sync/io/_bolt.py:874, in Bolt.fetch_all(self)
#     872 response = self.responses[0]
#     873 while not response.complete:
# --> 874     detail_delta, summary_delta = self.fetch_message()
#     875     detail_count += detail_delta
#     876     summary_count += summary_delta
#
# File /opt/miniconda3/envs/chat-lse/lib/python3.11/site-packages/neo4j/_sync/io/_bolt.py:860, in Bolt.fetch_message(self)
#     856 # Receive exactly one message
#     857 tag, fields = self.inbox.pop(
#     858     hydration_hooks=self.responses[0].hydration_hooks
#     859 )
# --> 860 res = self._process_message(tag, fields)
#     861 self.idle_since = monotonic()
#     862 return res
#
# File /opt/miniconda3/envs/chat-lse/lib/python3.11/site-packages/neo4j/_sync/io/_bolt5.py:370, in Bolt5x0._process_message(self, tag, fields)
#     368 self._server_state_manager.state = self.bolt_states.FAILED
#     369 try:
# --> 370     response.on_failure(summary_metadata or {})
#     371 except (ServiceUnavailable, DatabaseUnavailable):
#     372     if self.pool:
#
# File /opt/miniconda3/envs/chat-lse/lib/python3.11/site-packages/neo4j/_sync/io/_common.py:281, in LogonResponse.on_failure(self, metadata)
#     279 handler = self.handlers.get("on_summary")
#     280 Util.callback(handler)
# --> 281 raise Neo4jError.hydrate(**metadata)
#
# AuthError: {code: Neo.ClientError.Security.Unauthorized} {message: The client is unauthorized due to authentication failure.}
