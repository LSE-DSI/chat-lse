# %% [markdown]
# # NB08 – Benchmarking Results Analysis

# %%
import pandas as pd

# %%
df = pd.read_excel("../../data/ChatLSE Model Benchmarking.xlsx", header=1, usecols='B:N')

df.columns = ["tester_name", "model", "is_summariser", "question", "accuracy", "coherence", "fluency", "groundedness", "relevance", "full_json_log", "conversation_length", "comments", "total_score"]
df_scores = df[["model", "question", "accuracy", "coherence", "fluency", "groundedness", "relevance", "total_score"]].dropna()

df_scores["model"] = df_scores["model"].apply(lambda x: x.rstrip())
df_scores["model"] = df_scores["model"].apply(lambda x: x.lower())
df_scores["question"] = df_scores["question"].apply(lambda x: x.lower())

df_scores.head()
# Out:
#      model                                           question  accuracy  \
# 1  mistral                how do i apply for paternity leave?       5.0
# 2    llama                how do i apply for paternity leave?       4.0
# 3    llama  how do i get a "no objection" letter from the ...       5.0
# 4  mistral  how do i get a "no objection" letter from the ...       4.0
# 5  mistral              can i study abroad as an lse student?       2.0
#
#    coherence  fluency  groundedness  relevance  total_score
# 1        4.0      5.0           3.0        5.0         22.0
# 2        4.0      5.0           4.0        3.0         20.0
# 3        5.0      5.0           1.0        2.0         18.0
# 4        4.0      5.0           4.0        3.0         20.0
# 5        4.0      5.0           5.0        0.0         16.0

# %%
df_grouped_qn = df_scores.groupby(["question", "model"]).agg("mean").round(2)

df_grouped_qn
# Out:
#                                                             accuracy  \
# question                                           model
# a colleague has asked me for clarification on t... llama        5.00
# am i allowed to request to take a secondment fo... llama        4.50
#                                                    mistral      4.00
# am i eligible for any scholarships as a student... llama        4.00
#                                                    mistral      2.00
# can i study abroad as an lse student?              mistral      2.50
# can you give me a precise list of all of the co... llama        1.00
#                                                    mistral      1.00
# give me the latest lse blogs on inequality that... mistral      3.50
# how do i apply for paternity leave?                llama        4.50
#                                                    mistral      5.00
# how do i deal with an issue regarding a staff m... llama        3.00
#                                                    mistral      2.00
# how do i get a "no objection" letter from the l... llama        3.50
#                                                    mistral      4.00
# i am going on maternity leave. will i be guaran... mistral      5.00
# is it possible for me to switch from bsc econom... mistral      1.67
# my student has not attended class for a few wee... llama        5.00
#                                                    mistral      5.00
# what do i need to do to prepare for my student ... llama        4.00
#                                                    mistral      3.50
# where can i get support for my spring week appl... llama        4.00
#                                                    mistral      3.00
# who do i contact if i require urgent wellbeing ... llama        4.50
#                                                    mistral      4.00
# who do i contact to arrange a summer research a... llama        2.00
#                                                    mistral      2.00
#
#                                                             coherence  \
# question                                           model
# a colleague has asked me for clarification on t... llama         5.00
# am i allowed to request to take a secondment fo... llama         4.50
#                                                    mistral       3.00
# am i eligible for any scholarships as a student... llama         5.00
#                                                    mistral       3.50
# can i study abroad as an lse student?              mistral       4.25
# can you give me a precise list of all of the co... llama         3.00
#                                                    mistral       5.00
# give me the latest lse blogs on inequality that... mistral       4.50
# how do i apply for paternity leave?                llama         4.50
#                                                    mistral       4.00
# how do i deal with an issue regarding a staff m... llama         5.00
#                                                    mistral       4.00
# how do i get a "no objection" letter from the l... llama         4.50
#                                                    mistral       4.00
# i am going on maternity leave. will i be guaran... mistral       5.00
# is it possible for me to switch from bsc econom... mistral       3.67
# my student has not attended class for a few wee... llama         4.67
#                                                    mistral       5.00
# what do i need to do to prepare for my student ... llama         5.00
#                                                    mistral       5.00
# where can i get support for my spring week appl... llama         5.00
#                                                    mistral       5.00
# who do i contact if i require urgent wellbeing ... llama         4.50
#                                                    mistral       4.00
# who do i contact to arrange a summer research a... llama         5.00
#                                                    mistral       4.00
#
#                                                             fluency  \
# question                                           model
# a colleague has asked me for clarification on t... llama       5.00
# am i allowed to request to take a secondment fo... llama       4.50
#                                                    mistral     5.00
# am i eligible for any scholarships as a student... llama       5.00
#                                                    mistral     4.50
# can i study abroad as an lse student?              mistral     5.00
# can you give me a precise list of all of the co... llama       5.00
#                                                    mistral     5.00
# give me the latest lse blogs on inequality that... mistral     5.00
# how do i apply for paternity leave?                llama       5.00
#                                                    mistral     5.00
# how do i deal with an issue regarding a staff m... llama       5.00
#                                                    mistral     5.00
# how do i get a "no objection" letter from the l... llama       5.00
#                                                    mistral     5.00
# i am going on maternity leave. will i be guaran... mistral     5.00
# is it possible for me to switch from bsc econom... mistral     5.00
# my student has not attended class for a few wee... llama       4.67
#                                                    mistral     5.00
# what do i need to do to prepare for my student ... llama       5.00
#                                                    mistral     5.00
# where can i get support for my spring week appl... llama       5.00
#                                                    mistral     5.00
# who do i contact if i require urgent wellbeing ... llama       5.00
#                                                    mistral     5.00
# who do i contact to arrange a summer research a... llama       5.00
#                                                    mistral     5.00
#
#                                                             groundedness  \
# question                                           model
# a colleague has asked me for clarification on t... llama            5.00
# am i allowed to request to take a secondment fo... llama            5.00
#                                                    mistral          5.00
# am i eligible for any scholarships as a student... llama            5.00
#                                                    mistral          3.00
# can i study abroad as an lse student?              mistral          5.00
# can you give me a precise list of all of the co... llama            2.00
#                                                    mistral          1.00
# give me the latest lse blogs on inequality that... mistral          2.50
# how do i apply for paternity leave?                llama            4.50
#                                                    mistral          3.00
# how do i deal with an issue regarding a staff m... llama            5.00
#                                                    mistral          1.00
# how do i get a "no objection" letter from the l... llama            3.00
#                                                    mistral          4.00
# i am going on maternity leave. will i be guaran... mistral          5.00
# is it possible for me to switch from bsc econom... mistral          4.33
# my student has not attended class for a few wee... llama            5.00
#                                                    mistral          5.00
# what do i need to do to prepare for my student ... llama            5.00
#                                                    mistral          3.00
# where can i get support for my spring week appl... llama            5.00
#                                                    mistral          4.00
# who do i contact if i require urgent wellbeing ... llama            5.00
#                                                    mistral          5.00
# who do i contact to arrange a summer research a... llama            2.50
#                                                    mistral          1.00
#
#                                                             relevance  \
# question                                           model
# a colleague has asked me for clarification on t... llama         4.00
# am i allowed to request to take a secondment fo... llama         3.00
#                                                    mistral       5.00
# am i eligible for any scholarships as a student... llama         4.00
#                                                    mistral       2.00
# can i study abroad as an lse student?              mistral       2.00
# can you give me a precise list of all of the co... llama         1.00
#                                                    mistral       4.00
# give me the latest lse blogs on inequality that... mistral       5.00
# how do i apply for paternity leave?                llama         4.00
#                                                    mistral       5.00
# how do i deal with an issue regarding a staff m... llama         5.00
#                                                    mistral       3.00
# how do i get a "no objection" letter from the l... llama         2.50
#                                                    mistral       3.00
# i am going on maternity leave. will i be guaran... mistral       5.00
# is it possible for me to switch from bsc econom... mistral       1.33
# my student has not attended class for a few wee... llama         4.67
#                                                    mistral       5.00
# what do i need to do to prepare for my student ... llama         5.00
#                                                    mistral       3.50
# where can i get support for my spring week appl... llama         5.00
#                                                    mistral       3.50
# who do i contact if i require urgent wellbeing ... llama         4.50
#                                                    mistral       1.00
# who do i contact to arrange a summer research a... llama         3.50
#                                                    mistral       2.00
#
#                                                             total_score
# question                                           model
# a colleague has asked me for clarification on t... llama          24.00
# am i allowed to request to take a secondment fo... llama          21.50
#                                                    mistral        22.00
# am i eligible for any scholarships as a student... llama          23.00
#                                                    mistral        15.00
# can i study abroad as an lse student?              mistral        18.75
# can you give me a precise list of all of the co... llama          12.00
#                                                    mistral        16.00
# give me the latest lse blogs on inequality that... mistral        20.50
# how do i apply for paternity leave?                llama          22.50
#                                                    mistral        22.00
# how do i deal with an issue regarding a staff m... llama          23.00
#                                                    mistral        13.00
# how do i get a "no objection" letter from the l... llama          18.50
#                                                    mistral        20.00
# i am going on maternity leave. will i be guaran... mistral        25.00
# is it possible for me to switch from bsc econom... mistral        16.00
# my student has not attended class for a few wee... llama          24.00
#                                                    mistral        25.00
# what do i need to do to prepare for my student ... llama          24.00
#                                                    mistral        20.00
# where can i get support for my spring week appl... llama          24.00
#                                                    mistral        20.50
# who do i contact if i require urgent wellbeing ... llama          23.50
#                                                    mistral        19.00
# who do i contact to arrange a summer research a... llama          18.00
#                                                    mistral        14.00
